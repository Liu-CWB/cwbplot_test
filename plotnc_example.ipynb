# %%
#import numpy as np
#import netCDF4 as nc4
import matplotlib.pyplot as plt
#from mpl_toolkits.basemap import Basemap
from cwbplot import plotnc
#import wrf

#wrf_1 = nc4.Dataset("wrfout1")
#wrf_2 = nc4.Dataset("wrfout2")
fn1 = "wrfout1" 
fn2 = "wrfout2"

plotnc.nc_diff(fn1,fn2,"Q2 T2 T#10 QVAPOR#2",nrows=2,var_cmap="coolwarm coolwarm coolwarm twilight")
ax.savefig("tttt.png",format="png",dpi=350)
# Out:
# Q2
# T2
# T#10
# please specify the level
# QVAPOR#2
# please specify the level
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_264/3968536299.py in <module>
#      12
#      13 ax=plotnc.nc_diff(fn1,fn2,"Q2 T2 T#10 QVAPOR#2",nrows=2,var_cmap="coolwarm coolwarm coolwarm twilight")
# ---> 14 ax.savefig("tttt.png",format="png",dpi=350)
#
# AttributeError: 'NoneType' object has no attribute 'savefig'
